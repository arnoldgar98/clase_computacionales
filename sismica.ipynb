# %%
import numpy as np
import matplotlib.pylab as plt
x1=[0,15,30,45,60,75,90,105,120,135]
t1=[0.0049,0.01,0.0173,0.0233,0.0293,0.0353,0.0413,0.0473,0.0533,0.0587]
x2=[0,135,150,165,180,195]
t2=[0.0249,0.0587,0.0624,0.0662,0.0699,0.0737]
x3=[0,15]
t3=[0,0.01]
plt.figure(figsize=(8,8))
plt.title("Travel-time curves")
plt.xlabel("Distance(m)")
plt.ylabel("Time(ms)")
plt.plot(x1,t1,'o-',c="green",Label="refractada 1")
plt.plot(x2,t2,'o-',c="blue",Label="refractada 2")
plt.plot(x3,t3,'o-',c="gray",Label="Directa")
plt.legend()
plt.show()
